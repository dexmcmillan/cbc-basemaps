# %%
import geopandas

# %%
raw = geopandas.read_file("parliament4.geojson").to_crs("EPSG:4326")

raw
# Out:
#        Layer                                           geometry
# 0    Layer 1  LINESTRING (-93.12820 28.00112, -95.31963 28.0...
# 1    Layer 1  LINESTRING (-41.40463 26.10713, -42.75551 26.1...
# 2    Layer 1  LINESTRING (-42.96565 26.10713, -44.31652 26.1...
# 3    Layer 1  LINESTRING (-44.81300 24.58815, -46.16388 24.5...
# 4    Layer 1  LINESTRING (-44.82685 26.10713, -46.17773 26.1...
# ..       ...                                                ...
# 340  Layer 1  LINESTRING (-94.23892 32.41122, -95.58980 32.4...
# 341  Layer 1  LINESTRING (-94.23892 33.93021, -95.58980 33.9...
# 342  Layer 1  LINESTRING (-94.23892 35.44920, -95.58980 35.4...
# 343  Layer 1  LINESTRING (-94.23892 36.96818, -95.58980 36.9...
# 344  Layer 1  LINESTRING (-94.23892 38.50518, -95.58980 38.5...
#
# [345 rows x 2 columns]

# %%
parties = ["Vacant"] + ["Conservative"]*4 + ["Vacant"] + ["Conservative"]*112 + ["Bloc Quebecois"]*3 + ["Conservative"]*3 + ["Bloc Quebecois"]*12 + ["Vacant"] + ["Bloc Quebecois"]*5 + ["NDP"] + ["Bloc Quebecois"]*5 + ["NDP"] + ["Bloc Quebecois"]*5 + ["NDP"]*4 + ["Bloc Quebecois"]*2 + ["NDP"]*12 + ["Liberal"]*80 + ["Vacant"] + ["Liberal"]*66 + ["Vacant"] + ["Liberal"]*5 + ["Vacant"] + ["Liberal"]*3 + ["Green"] + ["Vacant"] + ["Independent"] + ["Liberal"]*3 + ["Green"] + ["Vacant"] + ["NDP"]*7 + ["N/A"]

raw["party"] = parties

raw
# Out:
#        Layer                                           geometry         party
# 0    Layer 1  LINESTRING (-93.12820 28.00112, -95.31963 28.0...        Vacant
# 1    Layer 1  LINESTRING (-41.40463 26.10713, -42.75551 26.1...  Conservative
# 2    Layer 1  LINESTRING (-42.96565 26.10713, -44.31652 26.1...  Conservative
# 3    Layer 1  LINESTRING (-44.81300 24.58815, -46.16388 24.5...  Conservative
# 4    Layer 1  LINESTRING (-44.82685 26.10713, -46.17773 26.1...  Conservative
# ..       ...                                                ...           ...
# 340  Layer 1  LINESTRING (-94.23892 32.41122, -95.58980 32.4...           NDP
# 341  Layer 1  LINESTRING (-94.23892 33.93021, -95.58980 33.9...           NDP
# 342  Layer 1  LINESTRING (-94.23892 35.44920, -95.58980 35.4...           NDP
# 343  Layer 1  LINESTRING (-94.23892 36.96818, -95.58980 36.9...           NDP
# 344  Layer 1  LINESTRING (-94.23892 38.50518, -95.58980 38.5...           N/A
#
# [345 rows x 3 columns]
